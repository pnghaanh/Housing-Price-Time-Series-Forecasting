# %%
import pandas as pd

# %%
sora_data = pd.read_csv('../data/modified/3M_SORA_rates_2005_2024_cleaned.csv')
sora_data.head()
# Out:
#   SORA Value Month  Compound SORA - 3 month
# 0          2005-10                 1.960476
# 1          2005-11                 2.195200
# 2          2005-12                 2.470248
# 3          2006-01                 2.795811
# 4          2006-02                 3.040975

# %%
sora_dict = {}
for (index, row) in sora_data.iterrows():
    sora_dict[row.iloc[0]] = row.iloc[1]

# %%
hdb_data = pd.read_csv('../data/modified/hdb_transaction_coordinates.csv')
hdb_data.drop(hdb_data.columns[[0, 1]], axis=1, inplace=True)
hdb_data.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
# 3            68.0  New Generation                 1979               63
# 4            68.0  New Generation                 1980               64
#
#    resale_price                address  Unnamed: 0_y  latitude   longitude
# ...

# %%
col_list = hdb_data.columns.tolist()
col_list.append('sora')
output_data = pd.DataFrame(columns=col_list)
for (index, row) in hdb_data.iterrows():
    output_row = row.tolist()
    output_row.append(sora_dict.get(row.iloc[0]))
    output_data.loc[len(output_data.index)] = output_row
output_data.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
# 3            68.0  New Generation                 1979               63
# 4            68.0  New Generation                 1980               64
#
#    resale_price                address  Unnamed: 0_y  latitude   longitude  \
# ...

# %%
output_data.to_csv('../data/modified/hdb_transaction_coordinates_sora.csv')
